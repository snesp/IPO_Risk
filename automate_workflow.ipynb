# %% [markdown]
# Automating the pipeline on AWS:
# 1. Generate python script from the python notebook
# 2. Create docker image containing the required environment to run the code
# 3. Create an ECR container and push the docker image to it
# 4. Push the python script and supporting files (IPO historic data) to a S3 bucket
# 5. (Performed on AWS interface) Set up the workflow on AWS CodePipeline

# %% [markdown]
# # Convert python notebook to python script

# %% [markdown]
# As we can only run the python script in the workflow automatically

# %%
# !pip install nbconvert
# !pip install sagemaker

# %%
# !jupyter nbconvert --to script 'ipo_risk.py' 'ipo_risk.ipynb'

# %% [markdown]
# # Creating Docker image containing the required environment to run the code

# %% [markdown]
# cleanup unused images

# %%
# !docker image prune -a -f
# Out:
# Deleted Images:
# untagged: 797452981712.dkr.ecr.us-east-2.amazonaws.com/sagemaker-processing-container:latest
# untagged: 797452981712.dkr.ecr.us-east-2.amazonaws.com/sagemaker-processing-container@sha256:fbd8077747b5f2fccc64615e4ae09ff74ee3a71ddc64786ed88dbd575a305d59
# untagged: sagemaker-processing-container:latest
# deleted: sha256:9b612396e3144abaa16d34787da38b9199f3cc9db6bef1897b154de6d9676d71
# untagged: 797452981712.dkr.ecr.us-east-2.amazonaws.com/ipo-risk-model:latest
# untagged: 797452981712.dkr.ecr.us-east-2.amazonaws.com/ipo-risk-model@sha256:01b5d3c0e25f98c424eed1e1e17049e58e1260331ff1e315ad0797b5db0f44c3
#
# Total reclaimed space: 0B

# %%
# %%writefile Dockerfile
#
# FROM python:3.7
#
# RUN pip3 install pandas numpy fuzzywuzzy pytrends re datetime math statistics scipy itertools statistics fuzzywuzzy py_stringmatching
# RUN pip3 install difflib sklearn matplotlib seaborn plotly requests bs4 gtab
#
# ENV PYTHONUNBUFFERED=TRUE
#
# ENTRYPOINT ["python3"]
# Out:
# Overwriting Dockerfile

# %% [markdown]
# # Create an ECR container that can store the Docker Image

# %%
import boto3

account_id = boto3.client('sts').get_caller_identity().get('Account')
region = boto3.Session().region_name
ecr_repository = 'sagemaker-processing-container'
tag = ':latest'
processing_repository_uri = '{}.dkr.ecr.{}.amazonaws.com/{}'.format(account_id, region, ecr_repository + tag)

# !docker build -t $ecr_repository docker
# !aws ecr get-login-password --region {region} | docker login --username AWS --password-stdin {account_id}.dkr.ecr.{region}.amazonaws.com
# !aws ecr create-repository --repository-name $ecr_repository
# !docker tag {ecr_repository + tag} $processing_repository_uri
# !docker push $processing_repository_uri
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  0.1s
# [+] Building 0.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  0.2s
# [+] Building 0.5s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  0.4s
# [+] Building 0.6s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  0.5s
# [+] Building 0.8s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  0.7s
# [+] Building 0.9s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  0.8s
# [+] Building 1.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  1.0s
# [+] Building 1.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  1.1s
# [+] Building 1.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  1.3s
# [+] Building 1.5s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  1.4s
# [+] Building 1.7s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  1.6s
# [+] Building 1.8s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  1.7s
# [+] Building 2.0s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  1.9s
# [+] Building 2.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.0s
# [+] Building 2.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.2s
# [+] Building 2.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.3s
# [+] Building 2.6s (3/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
# [+] Building 2.7s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          0.1s
# [+] Building 2.9s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          0.3s
# [+] Building 3.0s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          0.4s
# [+] Building 3.2s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          0.6s
# [+] Building 3.3s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          0.7s
# [+] Building 3.5s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          0.9s
# [+] Building 3.6s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          1.0s
# [+] Building 3.8s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          1.2s
# [+] Building 3.9s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          1.3s
# [+] Building 4.1s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          1.5s
#  => => # Collecting pandas
# [+] Building 4.2s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          1.6s
#  => => # Collecting pandas
# [+] Building 4.4s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          1.8s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (10.7 MB)
# [+] Building 4.5s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          1.9s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (10.7 MB)
# [+] Building 4.7s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          2.1s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (10.7 MB)
# [+] Building 4.8s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          2.2s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (10.7 MB)
# [+] Building 5.0s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          2.4s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (10.7 MB)
# [+] Building 5.1s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          2.5s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (10.7 MB)
# [+] Building 5.3s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          2.7s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (10.7 MB)
# [+] Building 5.4s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          2.9s
#  => => # Collecting pandas
#  => => #   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (10.7 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 10.7 MB/s e
#  => => # ta 0:00:00
# [+] Building 5.6s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          3.0s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 10.7 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting pytz>=2017.3
#  => => #   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 KB 19.5 MB/s e
#  => => # ta 0:00:00
# [+] Building 5.7s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          3.1s
#  => => # ta 0:00:00
#  => => # Collecting pytz>=2017.3
#  => => #   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 KB 19.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy>=1.19.2
# [+] Building 5.8s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          3.3s
#  => => #   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 KB 19.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy>=1.19.2
#  => => #   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (13.0 MB)
# [+] Building 6.0s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          3.4s
#  => => #   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 KB 19.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy>=1.19.2
#  => => #   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (13.0 MB)
# [+] Building 6.1s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          3.6s
#  => => #   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 KB 19.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting numpy>=1.19.2
#  => => #   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (13.0 MB)
# [+] Building 6.3s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          3.7s
#  => => # ta 0:00:00
#  => => # Collecting numpy>=1.19.2
#  => => #   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (13.0 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 23.4 MB/s e
#  => => # ta 0:00:00
# [+] Building 6.4s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          3.8s
#  => => #   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_17_aarch64.manylinux
#  => => # 2014_aarch64.whl (13.0 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 23.4 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting python-dateutil>=2.7.3
#  => => #   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# [+] Building 6.5s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          3.9s
#  => => # Collecting python-dateutil>=2.7.3
#  => => #   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# [+] Building 6.7s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          4.1s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 6.8s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          4.2s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 7.0s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          4.4s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 7.1s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          4.5s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 7.3s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          4.7s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 7.4s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          4.8s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 7.6s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          5.0s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 7.7s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          5.1s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 7.9s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          5.3s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 8.0s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          5.4s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 8.2s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          5.6s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 8.3s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          5.7s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 8.5s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          5.9s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 8.6s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          6.0s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 8.8s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          6.2s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 8.9s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          6.3s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 9.1s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          6.5s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 9.2s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          6.6s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 21.5 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting six>=1.5
#  => => #   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
#  => => # Installing collected packages: pytz, six, numpy, python-dateutil, pand
#  => => # as
# [+] Building 9.4s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          6.8s
#  => => # Successfully installed numpy-1.21.5 pandas-1.3.5 python-dateutil-2.8.2
#  => => #  pytz-2022.1 six-1.16.0
#  => => # WARNING: Running pip as the 'root' user can result in broken permissio
#  => => # ns and conflicting behaviour with the system package manager. It is re
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
# [+] Building 9.5s (4/5)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          7.0s
#  => => # Successfully installed numpy-1.21.5 pandas-1.3.5 python-dateutil-2.8.2
#  => => #  pytz-2022.1 six-1.16.0
#  => => # WARNING: Running pip as the 'root' user can result in broken permissio
#  => => # ns and conflicting behaviour with the system package manager. It is re
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
# [+] Building 9.7s (5/6)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          7.1s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.1s
# [+] Building 9.8s (5/6)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          7.1s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 10.0s (5/6)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          7.1s
#  => exporting to image                                                     0.4s
#  => => exporting layers                                                    0.4s
# [+] Building 10.1s (5/6)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          7.1s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 10.1s (6/6) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 196B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7-slim-buster  2.5s
#  => CACHED [1/2] FROM docker.io/library/python:3.7-slim-buster@sha256:8e6  0.0s
#  => => resolve docker.io/library/python:3.7-slim-buster@sha256:8e6150aea0  0.0s
#  => [2/2] RUN pip3 install pandas                                          7.1s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
#  => => writing image sha256:da85fc25107bdbe611260d42a21622d284f26072f9858  0.0s
#  => => naming to docker.io/library/sagemaker-processing-container          0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them
# Login Succeeded
#
# An error occurred (RepositoryAlreadyExistsException) when calling the CreateRepository operation: The repository with name 'sagemaker-processing-container' already exists in the registry with id '797452981712'
# The push refers to repository [797452981712.dkr.ecr.us-east-2.amazonaws.com/sagemaker-processing-container]
#
# da0edf0a: Preparing
# 1e19e1f0: Preparing
# 27b5c6ed: Preparing
# 621f0c8e: Preparing
# be1a526e: Preparing
# da0edf0a: Pushed   140.8MB/136.4MBAlatest: digest: sha256:24f851cb92b792b3665af900af0970ab81fef5dbf7681a8cd5fb2d7b38c362d5 size: 1582

# %% [markdown]
# # Move the script and required files to S3

# %% [markdown]
# Moving the script to S3

# %%
# !aws s3 cp ipo_historic_data.csv s3://ipo-risk-model/files/ipo_historic_data.csv
# Out:
# upload: ./ipo_historic_data.csv to s3://ipo-risk-model/files/ipo_historic_data.csv

# %%
# !aws s3 cp test.py s3://ipo-risk-model/files/test.py
# Out:
# upload: ./test.py to s3://ipo-risk-model/files/test.py
